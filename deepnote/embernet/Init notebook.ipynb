# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting geojson==2.5.0
#   Downloading geojson-2.5.0-py2.py3-none-any.whl (14 kB)
# Collecting rasterio
#   Downloading rasterio-1.2.10-cp37-cp37m-manylinux1_x86_64.whl (19.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 73.3 MB/s eta 0:00:00
# Collecting gdal==2.4.0
#   Downloading GDAL-2.4.0.tar.gz (564 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.6/564.6 KB 87.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting rasterstats==0.17.0
#   Downloading rasterstats-0.17.0-py3-none-any.whl (16 kB)
# Collecting rtree
#   Downloading Rtree-1.0.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 101.2 MB/s eta 0:00:00
# Collecting geoalchemy2==0.13.1
#   Downloading GeoAlchemy2-0.13.1-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 KB 15.1 MB/s eta 0:00:00
# Collecting networkx
#   Downloading networkx-2.6.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 122.3 MB/s eta 0:00:00
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 KB 48.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.7/site-packages (from rasterstats==0.17.0->-r ./requirements.txt (line 4)) (1.21.6)
# Collecting affine<3.0
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: cligj>=0.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterstats==0.17.0->-r ./requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: shapely in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterstats==0.17.0->-r ./requirements.txt (line 4)) (1.8.5.post1)
# Collecting simplejson
#   Downloading simplejson-3.19.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.0/127.0 KB 37.8 MB/s eta 0:00:00
# Requirement already satisfied: fiona in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterstats==0.17.0->-r ./requirements.txt (line 4)) (1.8.22)
# Requirement already satisfied: SQLAlchemy>=1.4 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from geoalchemy2==0.13.1->-r ./requirements.txt (line 6)) (1.4.42)
# Requirement already satisfied: packaging in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from geoalchemy2==0.13.1->-r ./requirements.txt (line 6)) (21.3)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.7/site-packages (from rasterio->-r ./requirements.txt (line 2)) (47.1.0)
# Requirement already satisfied: click-plugins in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterio->-r ./requirements.txt (line 2)) (1.1.1)
# Requirement already satisfied: certifi in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterio->-r ./requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: click>=4.0 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from rasterio->-r ./requirements.txt (line 2)) (8.1.3)
# Requirement already satisfied: attrs in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from rasterio->-r ./requirements.txt (line 2)) (22.1.0)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: typing-extensions>=3.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from rtree->-r ./requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: importlib-metadata in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from click>=4.0->rasterio->-r ./requirements.txt (line 2)) (5.0.0)
# Requirement already satisfied: pyparsing>=2.1.6 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from snuggs>=1.4.1->rasterio->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /shared-libs/python3.7/py/lib/python3.7/site-packages (from SQLAlchemy>=1.4->geoalchemy2==0.13.1->-r ./requirements.txt (line 6)) (1.1.3.post0)
# Requirement already satisfied: six>=1.7 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from fiona->rasterstats==0.17.0->-r ./requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: munch in /shared-libs/python3.7/py/lib/python3.7/site-packages (from fiona->rasterstats==0.17.0->-r ./requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from importlib-metadata->click>=4.0->rasterio->-r ./requirements.txt (line 2)) (3.9.0)
# Building wheels for collected packages: gdal, python-louvain
#   Building wheel for gdal (setup.py): started
#   Building wheel for gdal (setup.py): finished with status 'done'
#   Created wheel for gdal: filename=GDAL-2.4.0-cp37-cp37m-linux_x86_64.whl size=740258 sha256=0421d5fce71dd50a537ef1642f6554b145da8bc78298529d43901ac991870948
#   Stored in directory: /root/.cache/pip/wheels/cf/81/0c/ed742b724494d3486f59547e3c60093b9f0997b0b75c384eae
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9395 sha256=3c1340d0234b52f66ead449b5f9878af76830700c417e9575de6dee87c9104a8
#   Stored in directory: /root/.cache/pip/wheels/f6/23/43/a714ed84811240ec3e8e709b8594ecdfbc8ad36ca5d949e38e
# Successfully built gdal python-louvain
# Installing collected packages: geojson, gdal, snuggs, simplejson, rtree, networkx, affine, python-louvain, geoalchemy2, rasterio, rasterstats
#   Attempting uninstall: gdal
#     Found existing installation: GDAL 2.3.1
#     Not uninstalling gdal at /usr/local/lib/python3.7/site-packages, outside environment /root/venv
#     Can't uninstall 'GDAL'. No files were found to uninstall.
# Successfully installed affine-2.4.0 gdal-2.4.0 geoalchemy2-0.13.1 geojson-2.5.0 networkx-2.6.3 python-louvain-0.16 rasterio-1.2.10 rasterstats-0.17.0 rtree-1.0.1 simplejson-3.19.1 snuggs-1.4.7
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5eceab32-5823-49b2-9c95-72828e51fba3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
